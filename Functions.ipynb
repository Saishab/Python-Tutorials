# %% [raw]
# f(x)=2x+3
#
# if x = 5, what is f(x) ?
#
# In math, a function takes an input, processes it, and gives an output
# In Python, a function does the exact same thing!
#
#
# syntax:
#
# def function_name(parameters):
#     statement(s)

# %% [raw]
# A. Using print():

# %%
def f(x):
    y = 2*x + 3
    return y
    print(y)

# %%
function(4)
# Out:
# 11

# %%
f(4)
# Out:
# 11

# %%
def function(x):
    y = 2*x + 3
    return y

# %% [raw]
# B. Using return:

# %%
def mero_function(x):
    return 2*x + 1

# %%
mero_function(8)
# Out:
# 17

# %%
# create a function and see the student pass or fail    

def result(marks):
    
    if marks >= 40:
        return "Pass"
    else:
        return "Fail"

# %%
marks = int(input("Enter your marks"))

def result(marks):
    
    if marks >= 40:
        return "Pass"
    else:
        return "Fail"
# Out:
# Enter your marks 89

# %%
def result1():

    marks = int(input("Enter marks in physics")) 
    
    if marks >= 40:
        return "Pass"
    else:
        return "Fail"

# %%
def even_or_odd(number):
    #number = int(input("Enter a number"))
    if number%2 == 0:
        return "Even"
    else: 
        return "Odd"

# %%
even_or_odd(3)
# Out:
# 'Odd'

# %%
result(50)
# Out:
# 'Pass'

# %%
def square(x):
    return x*x

# %%
square(8)
# Out:
# 64

# %%
def squared(x):
    print(x*x)

# %%
squared(8)
# Out:
# 64

# %% [markdown]
# #### Functions: Arguments & Without Arguments

# %%
## without arguments 

def result():
    marks = int(input("Enter your marks: "))

    if marks >= 40:
        return "Pass"
    else:
        return "Fail"

# %%
result()
# Out:
# Enter your marks:  45
# 'Pass'

# %%
## with arguments 

def bigreko_result(marks):
    #marks = int(input("Enter your marks: "))

    if marks >= 40:
        return "Pass"
    else:
        return "Fail"

# %%
bigreko_result(67)
# Out:
# 'Pass'

# %%
def check_balance():
    balance = 25000
    withdrw = int(input("Enter your desired abount: "))

    if withdrw <= balance:
        return "You can proceed further"
    else:
        #return "Dear Customer, Not Sufficient balance"
        print('Dear Customer, Not Sufficient balance')

# %%
y = check_balance()
print(y)

# %%
def total():
    a = 
    b = 
    c = 
    d= 
    e =

# %%
add_garne_ho(4,5,6,7,8,9)
# Out:
# 39

# %% [markdown]
# ### *args : Arbitrary Positional Arguments
# ### **kwargs :  Arbitrary Keyword Arguments

# %%
def add_garne_ho(*a):
    return sum(a)
    #print("The sum is", sum(a))

# %%
add_garne_ho(2,3,4)
# Out:
# 9

# %%
print(sum)
# Out:
# <built-in function sum>

# %%
 def jod_diumna(*a):
     total = 0 
     for i in a:
         total = total + i
     print(total)

# %%
## not only numbers 

def neta_haru(*neta):
    for name in neta:
        print("The name of leader is", name)

# %%
#Write a function that multiplies all the numbers given as arguments.

# %%
def multiply(*nums):
    
    result = 1
    
    for n in nums:
        result *= n
    print("Product =", result)

# %%
# function that counts how many arguments are passed using *args.

# %%
def parameters(*a):
    print("The count is", len(a))

# %%
parameters(3,4,5)
# Out:
# The count is 3

# %%
#function that prints all even numbers from the given arguments.

# %%
def even_one(*even):
    for i in even:
        if i%2 == 0:
            print("Even number is",i) 
        #else: 
            #print("No even")

# %%
even_one(3,4,5,6)
# Out:
# Even number is 4
# Even number is 6

# %% [raw]
# **kwargs
# It allows a function to accept any number of named arguments
# Inside the function, all arguments are stored as a dictonary

# %%
def info_details(**data):
    print(data)

# %%
info_details(name = "KP", age = 75, location = 'Jhapa5')
# Out:
# {'name': 'KP', 'age': 75, 'location': 'Jhapa5'}

# %%
def student_form(**details):
    for key,values in details.items():  
        #.items() is a dictionary method which returns all key-value pairs in the dictionary as tuples (key, value).
        print(key,values)

# %%
student_form(name = "Sakshi", age = 22)
# Out:
# name Sakshi
# age 22

# %%
## **kwargs to take shoping details from users and print it

# %%
def order_summary(**samaan):
    for product, price in samaan.items():
        print(f"{product} costs Rs.{price}")

# %%
order_summary(shoes=2000, jacket=3500, bag=1500)
# Out:
# shoes costs Rs.2000
# jacket costs Rs.3500
# bag costs Rs.1500

# %% [raw]
# Use *args when you want a function to accept any number of positional (unnamed) arguments.
# Use **kwargs when you want a function to accept any number of keyword (named) arguments.

# %%
def marks():
    m1 = int(input("Enter your marks"))
    m2 = int(input("Enter your marks"))
    total = m1+m2
    return total

# %%
marks()
# Out:
# Enter your marks 34
# Enter your marks 43
# 77
